# %% [markdown]
#                        **tableu_basis_assignment**
#
#
# **answer1**: tableu is a data visualization  and bussiness intelligence tool used to analyze and present data in the forms of charts,graphs,maps and dashboards. its helps the decision makers  to understand the data easily  and make better business decisions.
# tableu is preferred  over spreadsheets because
# a)	It creates interactive and attractive visualizations.
# b)	It can handle large amounts of data efficiently.
# c)	It allows drag-and-drop analysis without coding.
# d)	It provides dashboards for quick insights.
#
# Industries where Tableau is mostly  used:
# 1.	1.Retail -To analyze sales, customer behavior, and inventory.
#
# 2.	Healthcare- To monitor patient records, hospital performance, and treatment outcomes.
#
# *********************************************************************
#
#
# **answer2**:-
#
# a) main types of fields :-
# Time-based -Order Date,Ship Date.
#  geographical:-Country, State, City, Region, postal Code
# 	Numerical: Sales, Profit, Quantity, Discount .
#
# b) four dimensions are: Category,Sub-Category,Region,State.
#
#    Four Measures:Sales,Profit,Quantity,Discount.
#
# ************************************************************************
#
#
# **answer3**:
#  Bar Chart showing Total Sales by Category.
#
#
#
#  ![answer3.jpg](data:image/jpeg;base64,...)
#
# Rows: Category
# Columns: Sales
# Aggregation applied to Sales: SUM (Total Sales)
#
#
# ***********************************************************************
#
# answer3:
# ![answer4.jpg](data:image/jpeg;base64,...)
#
# on Comparing Sales and Profit it caneasily identify products that generate high sales but low profit or even losses.
#
#
# *******************************************************************
#
#
# **answer5**:-
#
# Date Level: Month
# Reason: Monthly data shows trends clearly without being too detailed or too broad.
# line charts are suitable because
# •	They show trends over time.
# •	They help identify growth, decline, and seasonal patterns.
# •	They make it easy to compare changes over different periods.
#
#
# line chart for sales trend over date
#
# ![ans5.jpg](data:image/jpeg;base64,...)
#
#
# **********************************************************************
#
#
# answer6:-
#
# Steps:
# 1.	Drag Region to the Filters shelf.
# 2.	Select West.
# 3.	Drag Category to the Filters shelf.
# 4.	Select Technology.
# 5.	Click OK.
# Shelf used: Filters Shelf
#
# chart is like:
#
# ![ans6.jpg](data:image/jpeg;base64,...)
#
# ******************************************************
#
#
# answer7:-
#
# Geographical analysis helps businesses understand sales performance across different locations. It helps identify high-performing and low-performing regions for better planning.
# Steps to create a Sales by State Map:
# 1.	Drag State into the view.
# 2.	Tableau automatically creates a map.
# 3.	Drag Sales onto Color or Size.
# 4.	The map displays sales for each state.
#
# ******************************************************************
#
# answer8:-
#
# Worksheet:Displays one chart or visualization.
# Used to analyze a single aspect of the data.
#
# Dashboard:-Combines multiple worksheets in one screen.
# Shows complete business insights in one place.
#
# dashboards are usefulbecause of the following
# 1.	They provide a complete overview.
# 2.	Decision-makers can monitor multiple KPIs together.
# 3.	They support faster and better decision-making.
#
#
# *******************************************************************
#
# answer9:-
#
# Tableau Prep is a data preparation tool used to clean, organize, and combine data before analysis.
# Importance:
# a)Improves data quality.
# b)Removes errors and duplicate records.
# c)Makes analysis more accurate.
#
#
# ***********************************************************
#
# answer10:-
#
# a)
# for finding highest Profit by Category chart used  Bar Chart
#  for indicating Poor Performing Region: Bar Chart or Map
#  for showing Sales Over Time trend : Line Chart
#
# b) one key insight:- The Technology category generates the highest profit but  for some regions may have lower sales and profit, indicating areas that need improvement.
#
# c) Business decision-making:
# These insights help management to Focus on profitable products.
# 	Improve weak-performing regions.
# •	Plan marketing and inventory strategies.
# •	Increase overall business performance.
#
#
# **************************END*****************
